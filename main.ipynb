# %%
from src.main import main
main("/Users/mohdtahaabbas/SatSeg/data/images/intersection/intersection004.jpg")
# Out:
# Image loaded: /Users/mohdtahaabbas/SatSeg/data/images/intersection/intersection004.jpg (256x256, 3 channels)
# Calculating gradient magnitude...
# Gradient magnitude calculated.
#
# Processing for max_depth = 4...
# Finished max_depth = 4 in 0.02 seconds.
#
# Processing for max_depth = 6...
# Finished max_depth = 6 in 0.07 seconds.
#
# Processing for max_depth = 8...
# Finished max_depth = 8 in 0.28 seconds.
